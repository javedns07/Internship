# %%
#importing libraries
import selenium
import pandas as pd
from selenium import webdriver
from time import sleep
from selenium.webdriver.common.by import By

# %% [markdown]
# # Question 1

# %% [markdown]
# Write a python program which searches all the product under a particular product from www.amazon.in. The
# product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for
# guitars.

# %%
def search_amazon(product):
    # chrome browser to webdriver
    driver=webdriver.Chrome()

    # Load Amazon website
    driver.get("http://www.amazon.in/")

    #maximizing the window
    driver.maximize_window()
    
    # Find search box and input the product
    search_box = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
    search_box.send_keys(product)
    search_click=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
    search_click.click()


    # Wait for page to load
    sleep(2)

    # Find all product elements
    products = driver.find_elements(By.XPATH, '//div[@class="a-section a-spacing-base"]')

    # Extract and print information for each product
    for product in products[0:1]:
        product_title = product.find_element(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]').text
        try:
            product_price = product.find_element(By.XPATH, '//span[@class="a-price"]').text
        except:
            product_price = "Price not available"
        
        
        print("Product:", product_title)
        print("Price:", product_price)

        print()

#     # Quit WebDriver
    driver.quit()

# %%
if __name__ == "__main__":
    search_amazon("guitar")
# Out:
# Product: Kadence Frontier guitar with Online Guitar learning course , Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)
# Price: ₹4,499

# %% [markdown]
# # OR

# %%
# chrome browser to webdriver
driver=webdriver.Chrome()

# Load Amazon website
driver.get("http://www.amazon.in/")

#maximizing the window
driver.maximize_window()

inputU = input('please enter product here--->')
# Find search box and input the product
search_box = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
search_box.send_keys(inputU)
search_click=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search_click.click()


# Extract and print information for the product
for product in products[0:1]:
    product_title = product.find_element(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]').text
    try:
        product_price = product.find_element(By.XPATH, '//span[@class="a-price"]').text
    except:
        product_price = "Price not available"
        
        
    print("Product:", product_title)
    print("Price:", product_price)

    

# Quit WebDriver
driver.quit()
# Out:
# please enter product here--->guitar
# Product: Kadence Frontier guitar with Online Guitar learning course , Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)
# Price: ₹4,499

# %% [markdown]
# # Question 2

# %% [markdown]
# In the above question, now scrape the following details of each product listed in first 3 pages of your search
# results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then
# scrape all the products available under that product name. Details to be scraped are: "Brand
# Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
product_title=[]
product_brand=[]
product_price=[]
return_exchange=[]
expected_delivery=[]
availability=[]
Product_URL=[]

# %%
def search_amazon(product):
    # chrome browser to webdriver
    driver=webdriver.Chrome()

    # Load Amazon website
    driver.get("http://www.amazon.in/")

    #maximizing the window
    driver.maximize_window()
    
    # Find search box and input the product
    search_box = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
    search_box.send_keys(product)
    search_click=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
    search_click.click()


    # Wait for page to load
    sleep(1)


    # Find all product elements
    products=[]
    
#Iterating 3 pages # Find all product elements
    start=0
    end=3
    for i in range(start,end): 
        print("Scraping",i+1)
        #Scraping product urls
        for p in driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-4"]/a'):
            products.append(p.get_attribute('href'))
        next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div[1]/div/span[1]/div[1]/div[67]/div/div/span/a[3]')

    # Extract details for each product 

    for i in products:     #iterating each and every url to fetch full job details
        driver.get(i)             #taking each url one by one as an input
        sleep(1)
#  product_title 

        try:
            title = driver.find_element(By.XPATH,'//h1[@class="a-size-large a-spacing-none"]/span') 
            product_title.append(title.text)
        except: 
            product_title.append('-')
        
# product_brand 
        try:
            brand = driver.find_element(By.XPATH,'//td[@class="a-span9"]/span[1]') 
            product_brand.append(brand.text)
        except: 
            product_brand.append('-')
        
# product_price
        try:
            price = driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[4]/div[13]/div/div/div[4]/div[1]/span[2]/span[2]/span[2]') 
            product_price.append(price.text)
        except: 
            product_price.append('-')
        
#     return_exchange
        try:
            exchange = driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[4]/div[24]/div[2]/div/div/div/div[2]/div/ol/li[3]/div/span/div[2]/span') 
            return_exchange.append(exchange.text)
        except: 
            return_exchange.append('-')
        
        
#   expected_delivery 
        try:
            delivery = driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[1]/div[3]/div/div[1]/div/div/div/form/div/div/div/div/div[4]/div/div[3]/div[10]/div[1]/div/div/div[1]/span/span') 
            expected_delivery.append(delivery.text)
        except: 
            expected_delivery.append('-')
        
        
#       availability 
        try:
            avail = driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[1]/div[3]/div/div[1]/div/div/div/form/div/div/div/div/div[4]/div/div[5]/div/div[1]/span') 
            availability.append(avail.text)
        except: 
            availability.append('-')
    
  #  Product_URL      
        Product_URL['URL'].append(products) 
    
    
#     # Quit WebDriver
    driver.quit()

# %%
if __name__ == "__main__":
search_amazon("guitar")
# Out:
# Scraping 1
# Scraping 2
# Scraping 3

# %%
len(product_title)
# Out:
# 195

# %%
df = pd.DataFrame({"Title": product_title,"Brand Name": product_brand,"Price": product_price,"Return/Exchange": return_exchange,"Expected Delivery": expected_delivery,"Availability": availability})

# %%
df
# Out:
#                                                  Title    Brand Name Price  \
# 0    Kadence Frontier guitar with Online Guitar lea...       Kadence     -
# 1    Kadence rosewood Guitar Frontier Series, Elect...       Kadence     -
# 2    Kadence Slowhand Premium Jumbo Semi Acoustic G...       Kadence     -
# 3    Enya Nova Go Carbon Fiber Acoustic Guitar 1/2 ...          ENYA     -
# 4    Intern INT-38C Right hand Acoustic Guitar Kit,...        Intern     -
# ..                                                 ...           ...   ...
# 190  Yamaha FSX80C Semi acoustic cutaway guitar (na...        YAMAHA     -
# 191  BLUEBERRY B-D38, Acoustic Guitar Kit Inbuilt T...     blueberry     -
# 192  chiransi String Acoustic Guitar // Learning To...             -     -
# 193  PS Signature 41inch PURE SEFALI WOOD Acoustic ...  PS Signature     -
# 194  ROCKON 41 INCHES ACOUSTIC GUITAR WITH HARD THE...             -     -
#
#         Return/Exchange       Expected Delivery           Availability
# 0    7 days Replacement     Sunday, 18 February               In stock
# 1    7 days Replacement     Sunday, 18 February               In stock
# 2    7 days Replacement     Sunday, 18 February               In stock
# 3    7 days Replacement     Sunday, 18 February  Only 1 left in stock.
# 4    7 days Replacement     Sunday, 18 February               In stock
# ..                  ...                     ...                    ...
# 190                   -                       -                      -
# 191  7 days Replacement    Tuesday, 20 February               In stock
# 192                   -                       -                      -
# 193                   -  Wednesday, 21 February  Only 2 left in stock.
# 194                   -     Friday, 23 February  Only 1 left in stock.
#
# [195 rows x 6 columns]

# %%
df.to_csv('filename.csv', index=False)

# %%
# ..............................................................................................................................

# %%
# ..............................................................................................................................

# %% [markdown]
# # Question 3

# %% [markdown]
# Write a python program to access the search bar and search button on images.google.com and scrape 10
# images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
# # chrome browser to webdriver
driver = webdriver.Chrome()

#maximizing the window
driver.maximize_window()

# Load Google Images
driver.get('https://images.google.com')

# Keywords to search
keywords = [ 'fruits','cars', 'Guitar', 'Cakes','Machine Learning']

# Iterate over each keyword
for keyword in keywords:
    
    # Locate the search bar and input the keyword
    search_bar = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea')
    search_bar.send_keys(keyword)
      
        
    # Find the search button element and click it
    search_button = driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
    search_button.click()
    
    # Wait for images to load
    sleep(2)
    
    print('************************************Name of the Keyword*******************************************')
    
    #  scroll down  
    for _ in range(20):
        driver.execute_script("window.scrollBy(0,500)")
    
    sleep(5)
    
    # keyword and their image URLs
    image_URLs = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
    
#     Name of the Keyword
    print('*****************************************',keyword,'**************************************')
    
    # Scrape the image_URLs
    
    img_urls = []

    for image in image_URLs:
        source= image.get_attribute('src')
        if source is not None:
            if(source[0:4] == 'http'):
                img_urls.append(source)
    len(img_urls)
    
    
# scrape 10 images each for keywords 
    for i in range(len(img_urls)):
        if i >= 10:
            break
        print("Downloading {0} of {1} images" .format(i, 10))
        response= requests.get(img_urls[i])
    file = open(r"C:\Users\JAVED\Favorites\Fliprobo"+str(i)+".jpg", "wb")
    file.write(response.content)
        
  # Go back to the search page
    driver.execute_script("window.history.go(-1)")
    sleep(2)

# Close the browser
driver.quit()
# Out:
# ************************************Name of the Keyword*******************************************
# ***************************************** fruits **************************************
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images
# ************************************Name of the Keyword*******************************************
# ***************************************** cars **************************************
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images
# ************************************Name of the Keyword*******************************************
# ***************************************** Guitar **************************************
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images
# ************************************Name of the Keyword*******************************************
# ***************************************** Cakes **************************************
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images
# ************************************Name of the Keyword*******************************************
# ***************************************** Machine Learning **************************************
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images

# %% [markdown]
# # Question 4

# %% [markdown]
# Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com
# and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand
# Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
# empty lists
Brand_Name=[]
Storage_RAM_ROM=[]
P_F_Camera=[]
Display_size_Resolution=[]
Warranty=[]
Battery=[]
Price=[]
Product_URL=[]

# chrome browser to webdriver
driver=webdriver.Chrome()

# Load Amazon website
driver.get("https://www.flipkart.com/")

#maximizing the window
driver.maximize_window()
    
# Find search box and input the product
search_box = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/div/input")
search_box.send_keys('smartphone Oneplus Nord pixel 4A ')

# Find the search button element and click it
search_click=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/div/input")
search_click.submit()

# scraping information about smartphones


#Brand_Name 

BName=driver.find_elements(By.XPATH,'//div[@class="col col-7-12"]/div[1]')
try:
    for i in BName:
        Brand_Name.append(i.text)
except:
    Brand_Name.append('-')


    
# Storage_RAM_ROM

Storage=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"][1]')
try:
    for i in Storage:
        Storage_RAM_ROM.append(i.text)

except:
    Storage_RAM_ROM.append('-')       

    

# Display_size_Resolution
Display=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"][2]')
try:
    for i in Display:
        Display_size_Resolution.append(i.text)

except:
    Display_size_Resolution.append('-')       


    
# P_F_Camera
Camera=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"][3]')
try:
    for i in Camera:
        P_F_Camera.append(i.text)

except:
    P_F_Camera.append('-')       

    
    
# Battery
Battry=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"][4]')
try:
    for i in Battry:
        Battery.append(i.text)

except:
    Battery.append('-')       




# Warranty
Warrnty=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"][5]')
try:
    for i in Warrnty:
        Warranty.append(i.text)

except:
    Warranty.append('-') 
    
    
    
# Price

Prce=driver.find_elements(By.XPATH,'//div[@class="_3tbKJL"]/div/div[1]')
try:
    for i in Prce:
        Price.append(i.text)

except:
    Price.append('-') 
    

# Product_URL

Product=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
try:
    for i in Product:
        Product_URL.append(i.get_attribute('href'))

except:
    Product_URL.append('-') 
    
    
    
# dataframe
df=pd.DataFrame({'Brand':Brand_Name,'Storage':Storage_RAM_ROM,'Camera':P_F_Camera,'Display size Resolution':Display_size_Resolution,'Warranty':Warranty,'Battery':Battery,'Price':Price,'Product URL':Product_URL})

# %%
# results saved in a dataframe and CSV file.
df
df.to_csv('Smartphones.csv', index=False)
# Out:
#                                                 Brand                 Storage  \
# 0   OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...   8 GB RAM | 256 GB ROM
# 1          OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)   8 GB RAM | 128 GB ROM
# 2          OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)   8 GB RAM | 128 GB ROM
# 3          OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)   8 GB RAM | 128 GB ROM
# 4              OnePlus Nord CE 5G (Blue Void, 128 GB)   8 GB RAM | 128 GB ROM
# 5          OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)   6 GB RAM | 128 GB ROM
# 6                  OnePlus N20 SE (JADE WAVE, 128 GB)   4 GB RAM | 128 GB ROM
# 7                  OnePlus N20 SE (BLUE OASIS, 64 GB)    4 GB RAM | 64 GB ROM
# 8             OnePlus N20 SE (CELESTIAL BLACK, 64 GB)    4 GB RAM | 64 GB ROM
# 9          OnePlus 10 Pro 5G (Emerald Forest, 128 GB)   8 GB RAM | 128 GB ROM
# 10                 OnePlus 9 5G (Winter Mist, 128 GB)   8 GB RAM | 128 GB ROM
# 11               OnePlus 9R 5G (Carbon Black, 128 GB)   8 GB RAM | 128 GB ROM
# 12                OnePlus 9 5G (Astral Black, 128 GB)   8 GB RAM | 128 GB ROM
# 13                 OnePlus 9 5G (Winter Mist, 256 GB)  12 GB RAM | 256 GB ROM
# 14                  OnePlus Nord (Blue Marble, 64 GB)    6 GB RAM | 64 GB ROM
# 15                    OnePlus Nord (Gray Onyx, 64 GB)    6 GB RAM | 64 GB ROM
# 16                 OnePlus Nord (Blue Marble, 128 GB)   8 GB RAM | 128 GB ROM
# 17                   OnePlus Nord (Gray Onyx, 128 GB)   8 GB RAM | 128 GB ROM
# 18                 OnePlus Nord (Blue Marble, 256 GB)  12 GB RAM | 256 GB ROM
# 19                   OnePlus Nord (Gray Onyx, 256 GB)  12 GB RAM | 256 GB ROM
# 20         OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)   8 GB RAM | 128 GB ROM
# 21         OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)   6 GB RAM | 128 GB ROM
# 22         OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)   6 GB RAM | 128 GB ROM
# 23         OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)   6 GB RAM | 128 GB ROM
#
#                                        Camera  \
# 0                           108MP Rear Camera
# 1                            64MP Rear Camera
# 2                            64MP Rear Camera
# 3                            64MP Rear Camera
# 4                            64MP Rear Camera
# 5                            64MP Rear Camera
# 6                            50MP Rear Camera
# 7                            50MP Rear Camera
# 8                            50MP Rear Camera
# 9                            48MP Rear Camera
# 10                           48MP Rear Camera
# 11                           48MP Rear Camera
# 12                           48MP Rear Camera
# 13                           48MP Rear Camera
# 14  48MP + 8MP | 32MP + 8MP Dual Front Camera
# 15  48MP + 8MP | 32MP + 8MP Dual Front Camera
# 16  48MP + 8MP | 32MP + 8MP Dual Front Camera
# 17  48MP + 8MP | 32MP + 8MP Dual Front Camera
# 18  48MP + 8MP | 32MP + 8MP Dual Front Camera
# 19  48MP + 8MP | 32MP + 8MP Dual Front Camera
# 20                           64MP Rear Camera
# 21                           64MP Rear Camera
# 22                           64MP Rear Camera
# 23                           50MP Rear Camera
#
#                   Display size Resolution  \
# 0            17.07 cm (6.72 inch) Display
# 1            16.33 cm (6.43 inch) Display
# 2            16.33 cm (6.43 inch) Display
# 3            16.33 cm (6.43 inch) Display
# 4            16.33 cm (6.43 inch) Display
# 5            16.33 cm (6.43 inch) Display
# 6            16.66 cm (6.56 inch) Display
# 7            16.66 cm (6.56 inch) Display
# 8            16.66 cm (6.56 inch) Display
# 9             17.02 cm (6.7 inch) Display
# 10           16.64 cm (6.55 inch) Display
# 11           16.64 cm (6.55 inch) Display
# 12           16.64 cm (6.55 inch) Display
# 13           16.64 cm (6.55 inch) Display
# 14  16.36 cm (6.44 inch) Full HD+ Display
# 15  16.36 cm (6.44 inch) Full HD+ Display
# 16  16.36 cm (6.44 inch) Full HD+ Display
# 17  16.36 cm (6.44 inch) Full HD+ Display
# 18  16.36 cm (6.44 inch) Full HD+ Display
# 19  16.36 cm (6.44 inch) Full HD+ Display
# 20           16.33 cm (6.43 inch) Display
# 21           16.33 cm (6.43 inch) Display
# 22           16.33 cm (6.43 inch) Display
# 23           16.33 cm (6.43 inch) Display
#
#                                              Warranty           Battery  \
# 0   Domestic Warranty of 12 months on phone & 6 mo...  5000 mAh Battery
# 1                                     1 Year Warranty  4500 mAh Battery
# 2                                     1 Year Warranty  4500 mAh Battery
# 3                                            12 Month  4500 mAh Battery
# 4                                     1 Year Warranty  4500 mAh Battery
# 5                                     1 Year Warranty  4500 mAh Battery
# 6                                            12 Month  5000 mAh Battery
# 7                                        No Warranty.  5000 mAh Battery
# 8                                        No Warranty.  5000 mAh Battery
# 9   1 year manufacturer warranty for device and 6 ...  5000 mAh Battery
# 10                                             1 Year  4500 mAh Battery
# 11                                             1 Year  4500 mAh Battery
# 12                                          12 months  4500 mAh Battery
# 13                                             1 Year  4500 mAh Battery
# 14               Qualcomm® Snapdragon™ 765G Processor  4115 mAh Battery
# 15               Qualcomm® Snapdragon™ 765G Processor  4115 mAh Battery
# 16               Qualcomm® Snapdragon™ 765G Processor  4115 mAh Battery
# 17               Qualcomm® Snapdragon™ 765G Processor  4115 mAh Battery
# 18               Qualcomm® Snapdragon™ 765G Processor  4115 mAh Battery
# 19               Qualcomm® Snapdragon™ 765G Processor  4115 mAh Battery
# 20                                             1 Year  4500 mAh Battery
# 21                                    1 Year Warranty  4500 mAh Battery
# 22                                    1 Year Warranty  4500 mAh Battery
# 23                                           12 month  4500 mAh Battery
#
#       Price                                        Product URL
# 0   ₹21,335  https://www.flipkart.com/oneplus-nord-ce-3-lit...
# 1   ₹21,780  https://www.flipkart.com/oneplus-nord-ce-2-5g-...
# 2   ₹21,395  https://www.flipkart.com/oneplus-nord-ce-2-5g-...
# 3   ₹22,495  https://www.flipkart.com/oneplus-nord-ce-2-5g-...
# 4   ₹27,999  https://www.flipkart.com/oneplus-nord-ce-5g-bl...
# 5   ₹23,999  https://www.flipkart.com/oneplus-nord-ce-2-5g-...
# 6   ₹14,849  https://www.flipkart.com/oneplus-n20-se-jade-w...
# 7   ₹13,739  https://www.flipkart.com/oneplus-n20-se-blue-o...
# 8   ₹14,990  https://www.flipkart.com/oneplus-n20-se-celest...
# 9   ₹45,890  https://www.flipkart.com/oneplus-10-pro-5g-eme...
# 10  ₹33,199  https://www.flipkart.com/oneplus-9-5g-winter-m...
# 11  ₹32,599  https://www.flipkart.com/oneplus-9r-5g-carbon-...
# 12  ₹36,999  https://www.flipkart.com/oneplus-9-5g-astral-b...
# 13  ₹34,111  https://www.flipkart.com/oneplus-9-5g-winter-m...
# 14  ₹22,980  https://www.flipkart.com/oneplus-nord-blue-mar...
# 15  ₹22,689  https://www.flipkart.com/oneplus-nord-gray-ony...
# 16  ₹24,790  https://www.flipkart.com/oneplus-nord-blue-mar...
# 17  ₹24,600  https://www.flipkart.com/oneplus-nord-gray-ony...
# 18  ₹21,999  https://www.flipkart.com/oneplus-nord-blue-mar...
# 19  ₹22,999  https://www.flipkart.com/oneplus-nord-gray-ony...
# 20  ₹17,999  https://www.flipkart.com/oneplus-nord-ce-2-5g-...
# 21  ₹23,999  https://www.flipkart.com/oneplus-nord-ce-2-5g-...
# 22  ₹23,999  https://www.flipkart.com/oneplus-nord-ce-2-5g-...
# 23  ₹22,796  https://www.flipkart.com/oneplus-nord-ce-2-5g-...

# %% [markdown]
# # Question 5

# %% [markdown]
# Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
import regex as re
# chrome browser to webdriver
driver=webdriver.Chrome()

# Load google maps
driver.get("https://www.google.co.in/maps")

#maximizing the window
driver.maximize_window()

sleep(3)

city = input('Enter City Name : ') 

# Find search box and input the product
search_box = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/form/input")
# search_box.clear() 
sleep(2)
search_box.send_keys(city)
search_click=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/div[1]/button/span")
search_click.click()

sleep(2)

try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    print(lat_lng)
    if len(lat_lng):
        lat_lng_list = lat_lng[0].split(",")
        if len(lat_lng_list)>=2:
            lat = lat_lng_list[0]
            lng = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(lat, lng))

except Exception as e:
        print("Error: ", str(e))
# Out:
# Enter City Name : Pune
# URL Extracted:  https://www.google.co.in/maps/place/Pune,+Maharashtra/@18.5248706,73.6981531,11z/data=!3m1!4b1!4m6!3m5!1s0x3bc2bf2e67461101:0x828d43bf9d9ee343!8m2!3d18.5204303!4d73.8567437!16zL20vMDE1eTJx?entry=ttu
# ['18.5248706,73.6981531,11z/']
# Latitude = 18.5248706, Longitude = 73.6981531

# %% [markdown]
# # Question 6

# %% [markdown]
# Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
Brand_Name=[]
Specification=[]
Price=[]
Description=[]

# chrome browser to webdriver
driver=webdriver.Chrome()

# Load google maps
driver.get("https://www.digit.in/top-products/best-gaming-laptops-40.html")

#maximizing the window
driver.maximize_window()

#  Brand_Name 

BName=driver.find_elements(By.XPATH,'//div[@class="rh_gr_top_middle mb10 colored_rate_bar"]/h3')
try:
    for i in BName:
        Brand_Name.append(i.text)
except:
    Brand_Name.append('-')

# Specification

Spec=driver.find_elements(By.XPATH,'//div[@class="cegg-no-top-margin cegg-list-logo-title"]')
try:
    for i in Spec:
        Specification.append(i.text)
except:
    Specification.append('-')
    
# Price

Prc=driver.find_elements(By.XPATH,'//div[@class="cegg-price-row"]/div[1]')
try:
    for i in Prc:
        Price.append(i.text)
except:
    Price.append('-')
    
# Description

Descr=driver.find_elements(By.XPATH,'//div[@class="post-inner-wrapper leftbarcalc"]/p')
try:
    for i in Descr:
        Description.append(i.text)
except:
    Description.append('-')

    

df=pd.DataFrame({'Brand_Name':Brand_Name,'Price':Price,'Specification':Specification,'Description':Description})

# %%
# results saved in a dataframe and CSV file.
df
df.to_csv('digitin_laptop.csv', index=False)
# Out:
#                                           Brand_Name         Price  \
# 0       HP Omen 17-ck2008TX 13th Gen Core i7-13700HX  out of stock
# 1  MSI GT77 Titan 12UHS-054IN 12th Gen Core i9-12...  out of stock
# 2  Lenovo Legion 5i Pro 12th Gen Core i7-12700H (...  out of stock
# 3  ASUS ROG Strix Scar 18 G834JZ-N5041WS 13th Gen...   Rs. 289,990
# 4  Acer Predator Helios Neo 16 13th Gen Core i7-1...   Rs. 154,000
# 5  ASUS ROG Zephyrus G14 Ryzen 9-6900HS (GA402RJZ...  out of stock
# 6  MSI Cyborg 15 12th Gen Core i7-12650H (A12VF-2...   Rs. 118,300
#
#                                        Specification  \
# 0  HP Omen 13th Gen Intel Core i7-13700HX,17.3 in...
# 1  MSI Titan GT77, Intel 12th Gen. i9-12900HX, 43...
# 2  Lenovo Legion 5 Pro Intel Core i7-12700H 16" (...
# 3  ASUS ROG Strix Scar 18 (2023), Intel Core i9 1...
# 4  Acer Predator Helios Neo 16 Gaming Laptop 13th...
# 5  ASUS ROG Zephyrus G14 (2022), 14.0-inch (35.56...
# 6  MSI Cyborg 15 A12VF-205IN, Intel 12th Gen. i7-...
#
#                                          Description
# 0  We tested the HP OMEN 17 2023 at our digit tes...
# 1  This laptop won our best performance award las...
# 2  This Lenovo Legion 5i Pro gaming laptop hits t...
# 3  If a 17-inch display on a gaming laptop no lon...
# 4  The Acer Predator series of gaming laptops has...
# 5  Another ASUS laptop makes it to our list, and ...
# 6  One of the newest gaming laptop series from MS...

# %% [markdown]
# # Question 7

# %% [markdown]
# Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped:
# “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
Rank=[]
Name=[]
Net_worth=[]
Age =[]
Citizenship=[]
Source=[]
Industry=[]


# chrome browser to webdriver
driver=webdriver.Chrome()

# Load google maps
driver.get("https://www.forbes.com/")

#maximizing the window
driver.maximize_window()

sleep(2)
#finding and clicking to access "The Richest People In The World" page
search_box = driver.find_element(By.XPATH,"/html/body/div[1]/header/nav/div[1]/div[1]/div/div")
search_box.click()
sleep(2)
search1_box = driver.find_element(By.XPATH,'//div[@role="button"]/span[1][1]')
search1_box.click()
sleep(2)
search2_box = driver.find_element(By.XPATH,'//li[@class="TjJgrPSg _2bNo56RE secondary"]/a')
search2_box.click()

sleep(2)

#Rank 

Rnk=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][1]/div')
try:
    for i in Rnk:
        Rank.append(i.text)
except:
    Rank.append('-')

#Name 

Nam=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][2]/div')
try:
    for i in Nam:
        Name.append(i.text)
except:
    Name.append('-')
    
#Net_worth 

worth=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][3]/div')
try:
    for i in worth:
        Net_worth.append(i.text)
except:
    Net_worth.append('-')
    
#Age 

age_no=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][4]/div')
try:
    for i in age_no:
        Age.append(i.text)
except:
    Age.append('-')
    

#Source 

Src=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][7]/div')
try:
    for i in Src:
        Source.append(i.text)
except:
    Source.append('-')

#Industry 

Indsty=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][6]/div')
try:
    for i in Indsty:
        Industry.append(i.text)
except:
    Industry.append('-')
    
    
# #Citizenship 

cty=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][5]')
try:
    for i in cty:
        Citizenship.append(i.text)
except:
    Citizenship.append('-')
# //div[@class="TableRow_row__L-0Km"]/div[5]
    
df=pd.DataFrame({'Rank':Rank,'Name':Name,'Net_worth':Net_worth,'Age':Age,'Citizenship':Citizenship,'Source':Source,'Industry':Industry})

# %%
len(Citizenship)
# Out:
# 200

# %%
df
# Out:
#     Rank                      Name Net_worth Age    Citizenship  \
# 0      1  Bernard Arnault & family    $211 B  74         France
# 1      2                 Elon Musk    $180 B  51  United States
# 2      3                Jeff Bezos    $114 B  59  United States
# 3      4             Larry Ellison    $107 B  78  United States
# 4      5            Warren Buffett    $106 B  92  United States
# ..   ...                       ...       ...  ..            ...
# 195  195               Jin Baofang    $9.6 B  70          China
# 196  195        Luo Liguo & family    $9.6 B  67          China
# 197  195              Marijke Mars    $9.6 B  58  United States
# 198  195               Pamela Mars    $9.6 B  62  United States
# 199  195              Valerie Mars    $9.6 B  64  United States
#
#                     Source            Industry
# 0         Fashion & Retail                LVMH
# 1               Automotive       Tesla, SpaceX
# 2               Technology              Amazon
# 3               Technology              Oracle
# 4    Finance & Investments  Berkshire Hathaway
# ..                     ...                 ...
# 195                 Energy        Solar panels
# 196          Manufacturing           Chemicals
# 197        Food & Beverage     Candy, pet food
# 198        Food & Beverage     Candy, pet food
# 199        Food & Beverage     Candy, pet food
#
# [200 rows x 7 columns]

# %% [markdown]
# # Question 8

# %% [markdown]
# Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted
# from any YouTube Video

# %%
# empty lists
Comments=[]
Comment_upvote=[]
time=[]


# chrome browser to webdriver
driver=webdriver.Chrome()

# Load google maps
driver.get("https://www.youtube.com/")

#maximizing the window
driver.maximize_window()


search_box = driver.find_element(By.XPATH,'//div[@class="ytd-searchbox-spt"]/input')
search_box.send_keys('songs')
sleep(2)
search_click=driver.find_element(By.XPATH,"/html/body/ytd-app/div[1]/div/ytd-masthead/div[4]/div[2]/ytd-searchbox/button/yt-icon")
search_click.click()
sleep(2)
search1_click=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-search/div[1]/ytd-two-column-search-results-renderer/div/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-search-pyv-renderer[1]/div/ytd-ad-slot-renderer/div/ytd-in-feed-ad-layout-renderer/div/ytd-promoted-video-renderer/div/div/div[1]/a/div/div[1]/h3')
search1_click.click()

sleep(5)

# for _ in range(1000):
#     driver.execute_script("window.srollBy(0,1000)")
    
for _ in range(500):
    driver.execute_script("window.scrollBy(0,200)")

sleep(3)


# Comments
comnt=driver.find_elements(By.XPATH,'//div[@class="style-scope ytd-expander"]/yt-formatted-string[1]')
try:
    for i in comnt:
        Comments.append(i.text)
except:
    Comments.append('-')

    
    
# Comment_upvote
comnt_up=driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-comment-action-buttons-renderer"][2]')
try:
    for i in comnt_up:
        Comment_upvote.append(i.text)
except:
    Comment_upvote.append('-')

    
    
    
# time
tim=driver.find_elements(By.XPATH,'//yt-formatted-string[@class="published-time-text style-scope ytd-comment-renderer"]/a')
try:
    for i in tim:
        time.append(i.text)
except:
    time.append('-')

    
    
# dataframe
df=pd.DataFrame({'Comments':Comments,'Comment_upvote':Comment_upvote,'time':time})

# %%
df
# Out:
#                                               Comments Comment_upvote  \
# 0    Real magic is created when cultures and people...            272
# 1    Dosanjhawala With Quickstyle Is Epic Duo With ...             56
# 2             What a Collab, this song is such a vibe.              7
# 3       One of the most unexpected crossovers! Crazyyy             29
# 4    Diljit x quickstyle x cokestudio  is everythin...             24
# ..                                                 ...            ...
# 455                                          Superb!
# 456                                              भारत
# 457              Here for diljeet bt bonus quick style
# 458                                            Sunder               1
# 459                                              Good               1
#
#            time
# 0    5 days ago
# 1    8 days ago
# 2    6 days ago
# 3    9 days ago
# 4    9 days ago
# ..          ...
# 455  8 days ago
# 456   1 day ago
# 457  4 days ago
# 458  9 days ago
# 459  5 days ago
#
# [460 rows x 3 columns]

# %% [markdown]
# # Question 9

# %% [markdown]
# Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall
# reviews,facilities and property description

# %%
# empty list
Names=[]
Ratingss=[]
Total_review=[]
Overall_reviewss=[]
Facilitiess=[]
Property_descriptions=[]
Hostelworld_says=[]
distance=[]

# chrome browser to webdriver
driver=webdriver.Chrome()

# Load google maps
driver.get("https://www.hostelworld.com/")

#maximizing the window
driver.maximize_window()

search_box = driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/input ')
search_box.send_keys('London')
sleep(2)

search1_click=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[2]/div/ul/li[2]/button/div[2]')
search1_click.click()

# sleep(2)

search_click=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[5]/button[2]')
search_click.click()

sleep(2)

distance=[]
dist=driver.find_elements(By.XPATH,'//span[@class="distance-description"]')
try:
    for i in dist:
        distance.append(i.text)
except:
    distance.append('-')

properties_URLs=[]
#Scraping product urls
for p in driver.find_elements(By.XPATH,'//div[@class="property-list"]/div/div/div[4]/div/a/a'):
    properties_URLs.append(p.get_attribute('href'))

sleep(7)

    
for i in properties_URLs:     #iterating each and every url to fetch full job details
        driver.get(i)             #taking each url one by one as an input
        sleep(1)
        
# # 1.Name
        try:
            title = driver.find_element(By.XPATH,'//div[@class="headline-container"]/div/h1/div') 
            Names.append(title.text)
        except: 
            Names.append('-')

# #2. Ratings
        try:
            Rating = driver.find_element(By.XPATH,'//section[@name="ms-page"]/div[8]/div/div/div[1]/div[1]') 
            Ratingss.append(Rating.text)
        except: 
            Ratingss.append('-')
            
# #3.Total_reviews
        try:
            Total_rev = driver.find_element(By.XPATH,'//section[@name="ms-page"]/div[8]/div/div/div[1]/div[2]/div[2]') 
            Total_review.append(Total_rev.text.replace('Total Reviews',' '))
        except: 
            Total_review.append('-')  

# #4.Overall_reviews
        try:
            Overall_rev = driver.find_element(By.XPATH,'//section[@name="ms-page"]/div[8]/div/div[1]/div[1]/div[2]/div[1]') 
            Overall_reviewss.append(Overall_rev.text)
        except: 
            Overall_reviewss.append('-')  

# #5.Hostelworld_says
        try:
            Hostelworld_say = driver.find_element(By.XPATH,'//section[@name="ms-page"]/div[8]/div/div[1]/div[1]/div[2]/div[1]') 
            Hostelworld_says.append(Hostelworld_says.text)
        except: 
            Hostelworld_says.append('-') 

#6.Property_description
        try:
            descr = driver.find_element(By.XPATH,'//section[@name="ms-page"]/div[8]/div/div[2][1]//div//div/div[2]') 
            Property_descriptions.append(descr.text)
        except: 
            Property_descriptions.append('-') 

# #7.Facilities
        try:
            Facility = driver.find_element(By.XPATH,'//section[@name="ms-page"]/div[12]/div//ul/li[2]/ul/li[4]') 
            Facilitiess.append(Facility.text)
        except: 
            Facilitiess.append('-')

# %%
len(distance)
# Out:
# 30

# %%
df=pd.DataFrame({'Name':Names,'Ratings':Ratingss,'distance':distance,'Total_reviews':Total_review,'Overall_reviews':Overall_reviewss,'Facilities':Facilitiess,'Property_description':Property_descriptions})

# %%
df
# Out:
#                                        Name Ratings  \
# 0               Wombat's City Hostel London     9.1
# 1             Palmers Lodge - Swiss Cottage     8.8
# 2                  St Christopher's Village     7.8
# 3                          NX London Hostel     8.9
# 4                       Onefam Notting Hill     9.6
# 5                      Urbany Hostel London     9.5
# 6                           Onefam Waterloo     9.6
# 7                        No.8 Seven Sisters     7.8
# 8                           Astor Hyde Park     8.2
# 9         Safestay London Elephant & Castle     7.3
# 10                         Astor Museum Inn     8.4
# 11             No.8 Willesden Hostel London     7.2
# 12               Smart Hyde Park Inn Hostel     7.8
# 13              Smart Russell Square Hostel     7.5
# 14  Safestay London Kensington Holland Park     6.9
# 15                                 Clink261     8.1
# 16      Hostelle - women only hostel London     8.8
# 17                  Queen Elizabeth Chelsea     7.4
# 18                  Prime Backpackers Angel     8.7
# 19                 YHA London Oxford Street     9.0
# 20                       London Backpackers     8.0
# 21               Kabannas London St Pancras     8.2
# 22             St Christopher's Hammersmith     7.6
# 23                           Astor Victoria     7.3
# 24                         Astor Kensington     8.4
# 25                           Phoenix Hostel     6.3
# 26                  St Christopher's Camden     7.2
# 27                       YHA London Central     9.1
# 28  St Christopher's Inn - Liverpool Street     8.2
# 29          St Christopher's Shepherds Bush     7.7
#
#                      distance Total_reviews Overall_reviews  \
# 0    - 3.6km from city centre       15961            Superb
# 1    - 6.5km from city centre       15992          Fabulous
# 2    - 1.8km from city centre       12893         Very Good
# 3    - 6.1km from city centre        2165          Fabulous
# 4    - 5.5km from city centre        2621            Superb
# 5    - 5.4km from city centre        1137            Superb
# 6    - 0.7km from city centre         160            Superb
# 7      - 9km from city centre        4183         Very Good
# 8    - 4.3km from city centre       12338          Fabulous
# 9    - 1.7km from city centre        5288         Very Good
# 10   - 2.2km from city centre        9464          Fabulous
# 11    - 10km from city centre        5209         Very Good
# 12     - 5km from city centre        6805         Very Good
# 13   - 2.6km from city centre       10218         Very Good
# 14   - 5.8km from city centre        1793              Good
# 15   - 3.2km from city centre         533          Fabulous
# 16   - 5.1km from city centre         125          Fabulous
# 17   - 5.7km from city centre        3697         Very Good
# 18   - 3.6km from city centre         875          Fabulous
# 19   - 2.1km from city centre        4704            Superb
# 20  - 11.9km from city centre        4569          Fabulous
# 21   - 3.3km from city centre        2981          Fabulous
# 22   - 7.5km from city centre        4397         Very Good
# 23   - 1.8km from city centre       15106         Very Good
# 24   - 4.9km from city centre        6597          Fabulous
# 25   - 4.2km from city centre        4629              Good
# 26   - 4.3km from city centre        4141         Very Good
# 27   - 2.9km from city centre        4790            Superb
# 28   - 3.2km from city centre         560          Fabulous
# 29     - 7km from city centre         837         Very Good
#
#                   Facilities  \
# 0                          -
# 1                   Elevator
# 2                          -
# 3   Self-Catering Facilities
# 4               Flexible NRR
# 5                          -
# 6                   Adaptors
# 7            Bicycle Parking
# 8                   Adaptors
# 9                   Adaptors
# 10                  Adaptors
# 11    Breakfast Not Included
# 12    Breakfast Not Included
# 13    Breakfast Not Included
# 14    Breakfast Not Included
# 15                  Adaptors
# 16                  Cable TV
# 17                  Adaptors
# 18                       BBQ
# 19    Breakfast Not Included
# 20    Breakfast Not Included
# 21                  Elevator
# 22             Reading Light
# 23             Meeting Rooms
# 24                  Adaptors
# 25    Breakfast Not Included
# 26    Breakfast Not Included
# 27               Common Room
# 28          Air Conditioning
# 29                       BBQ
#
#                                  Property_description
# 0   A safe haven in the middle of the metropolis: ...
# 1   Palmers Lodge Swiss Cottage is set in what one...
# 2   Hostelworld visitors have said St Christopher'...
# 3   Welcome to NX London Hostel!\n\nPLEASE READ IN...
# 4   The perfect place for solo travelers to connec...
# 5   Welcome to Urbany Hostel London! Ideal for the...
# 6   Come join us at our newest Onefam location in ...
# 7   For Great Facilities, Comfort & Affordability ...
# 8   Note: 18-40 yrs old only. Astor Hyde Park won ...
# 9   Safestay at Elephant and Castle is located in ...
# 10  Note: 18-40 yrs old only. Astor Museum won 1st...
# 11  At No.8 we take pride in our Customer Service ...
# 12  Smart Hyde Park Inn Hostel is perfectly locate...
# 13  Many Hostelworld guests who visit Smart Russel...
# 14  Safestay Holland Park\n\nSafestay Holland Park...
# 15  Clink261 is near King's Cross St Pancras stati...
# 16  Hostelle is the first and only all-women hoste...
# 17  PLEASE NOTE WE ONLY ACCEPT GUESTS FROM THE AGE...
# 18  The hostel is housed in a historic building in...
# 19  YHA London Oxford Street is all about location...
# 20  IMPORTANT NOTICE: \n\nThis hostel is for 18 - ...
# 21  Kabannas London St Pancras has friendly recept...
# 22  The friendly, attentive, and welcoming staff o...
# 23  Note: 18-40 yrs old only. Astor Victoria won 1...
# 24  Note: 18-40 yrs old only. Astor Kensington won...
# 25  The Phoenix Bar & Hostel, housed in a homely E...
# 26  If you're looking to explore the markets and m...
# 27  YHA London Central is often mentioned by our g...
# 28  Our Liverpool Street hostel is the newest of o...
# 29  St Christopher's Shepherds Bush has been highl...
